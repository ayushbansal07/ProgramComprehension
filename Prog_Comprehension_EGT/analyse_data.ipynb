# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("data/V3.xlsx")
data.head()
# Out:
#    frame_no  line_no token_name  count  Timestart  TimeEnd stmt_name  \
# 0       100        0    'blank'     24       5736     6490   'blank'
# 1       100        1  'include'      3       6523     6589   'blank'
# 2       100        2  'include'      2       6622     6655   'blank'
# 3       100        1  'include'      1       6687     6687   'blank'
# 4       100        2  'include'      1       6720     6720   'blank'
#
#    startline block_name  start_line  end_line function_name  start_line.1  \
# 0          0    'blank'           0         0       'blank'             0
# 1          0    'blank'           0         0       'blank'             0
# 2          0    'blank'           0         0       'blank'             0
# 3          0    'blank'           0         0       'blank'             0
# 4          0    'blank'           0         0       'blank'             0
#
#    end_line.1
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
data_np = np.array(data)
data_np
# Out:
# array([[100, 0, "'blank'", ..., "'blank'", 0, 0],
#        [100, 1, "'include'", ..., "'blank'", 0, 0],
#        [100, 2, "'include'", ..., "'blank'", 0, 0],
#        ...,
#        [101, 0, "'blank'", ..., "'blank'", 0, 0],
#        [101, 38, "'10'", ..., "'FunctionBody2'", 23, 44],
#        [101, 38, "'/'", ..., "'FunctionBody2'", 0, 0]], dtype=object)

# %%
srt_by_ct = sorted(data_np,key = lambda x:x[3],reverse=True)

# %%
srt_by_ct = np.array(srt_by_ct)
for data in srt_by_ct:
    if data[2] != '\'blank\'':
        print(data[2][1:-1],data[3])
# Out:
# "%disnotanArmstrongnumber.\n" 106
# "Error!Factorialofanegativenumberdoesn''texist." 35
# negative 27
# "%disnotanArmstrongnumber.\n" 20
# void 19
# "Factorialof%d=%llu" 19
# "Inputaninteger\n" 17
# "Enteraninteger:" 16
# / 15
# factorial 13
# factorial 11
# "%disanArmstrongnumber.\n" 11
# factorial 10
# unsigned 10
# 10 10
# != 10
# "Enteraninteger:" 9
# "Factorialof%d=%llu" 9
# factorial 8
# unsigned 8
# "Enteraninteger:" 8
# scanf 8
# void 7
# printf 7
# != 7
# remainder 7
# int 6
# factorial 6
# i 6
# 0 6
# 10 6
# factorial 5
# "Enteraninteger:" 5
# printf 5
# 0 5
# remainder 5
# remainder 5
# remainder 5
# 10 5
# factorial 4
# "Enteraninteger:" 4
# show 4
# 0 4
# a 4
# *= 4
# & 4
# digits 4
# 10 4
# "%disanArmstrongnumber.\n" 4
# "%disanArmstrongnumber.\n" 4
# "Inputaninteger\n" 4
# include 3
# include 3
# int 3
# unsigned 3
# unsigned 3
# printf 3
# "Enteraninteger:" 3
# factorial 3
# printf 3
# scanf 3
# show 3
# "Factorialof%d=%llu" 3
# "Inputaninteger\n" 3
# "Inputaninteger\n" 3
# "Inputaninteger\n" 3
# digits 3
# number 3
# 10 3
# 10 3
# temp 3
# "%disanArmstrongnumber.\n" 3
# "Inputaninteger\n" 3
# ; 3
# 10 3
# 10 3
# include 2
# include 2
# include 2
# long 2
# unsigned 2
# unsigned_blank 2
# unsigned 2
# unsigned 2
# long 2
# "Enteraninteger:" 2
# factorial 2
# "Enteraninteger:" 2
# "%d" 2
# "%d" 2
# "Enteraninteger:" 2
# show 2
# / 2
# ( 2
# "Error!Factorialofanegativenumberdoesn''texist." 2
# factorial 2
# armstrong_no 2
# 0 2
# "Inputaninteger\n" 2
# ) 2
# = 2
# & 2
# n 2
# & 2
# "Inputaninteger\n" 2
# n 2
# temp 2
# digits 2
# temp 2
# temp 2
# temp 2
# temp 2
# temp 2
# 10 2
# / 2
# digits 2
# "%disnotanArmstrongnumber.\n" 2
# temp 2
# power 2
# include 1
# include 1
# stdio 1
# stdio 1
# include 1
# include 1
# include 1
# factorial 1
# factorial 1
# void 1
# unsigned 1
# "Enteraninteger:" 1
# long 1
# int 1
# n 1
# unsigned 1
# printf 1
# printf 1
# unsigned 1
# printf 1
# printf 1
# ( 1
# "Enteraninteger:" 1
# & 1
# n 1
# "Enteraninteger:" 1
# long 1
# factorial 1
# factorial 1
# "Enteraninteger:" 1
# "Enteraninteger:" 1
# "Enteraninteger:" 1
# factorial 1
# "Enteraninteger:" 1
# "Enteraninteger:" 1
# printf 1
# scanf 1
# ( 1
# "Enteraninteger:" 1
# ( 1
# "%d" 1
# & 1
# n 1
# "Enteraninteger:" 1
# ) 1
# n 1
# ) 1
# & 1
# show 1
# scanf 1
# show 1
# error 1
# "%d" 1
# "%d" 1
# error 1
# ( 1
# "%d" 1
# show 1
# "%d" 1
# show 1
# n 1
# error 1
# "Error!Factorialofanegativenumberdoesn''texist." 1
# 0 1
# printf 1
# user 1
# factorial 1
# "Error!Factorialofanegativenumberdoesn''texist." 1
# user 1
# "Error!Factorialofanegativenumberdoesn''texist." 1
# user 1
# negative 1
# ++ 1
# *= 1
# temp 1
# , 1
# 0 1
# "Inputaninteger\n" 1
# = 1
# 0 1
# "Inputaninteger\n" 1
# "Inputaninteger\n" 1
# 0 1
# temp 1
# , 1
# temp 1
# ; 1
# ; 1
# remainder 1
# digits 1
# remainder 1
# ) 1
# ; 1
# , 1
# remainder 1
# ; 1
# ) 1
# digits 1
# ; 1
# digits 1
# = 1
# 0 1
# ; 1
# digits 1
# "Inputaninteger\n" 1
# n 1
# "Inputaninteger\n" 1
# & 1
# ) 1
# ; 1
# digits 1
# "Inputaninteger\n" 1
# digits 1
# n 1
# of 1
# n 1
# "Inputaninteger\n" 1
# ) 1
# & 1
# , 1
# number 1
# 0 1
# ) 1
# 0 1
# ) 1
# temp 1
# 10 1
# / 1
# / 1
# 10 1
# ; 1
# 0 1
# 10 1
# temp 1
# digits 1
# temp 1
# digits 1
# 0 1
# 0 1
# temp 1
# = 1
# != 1
# temp 1
# ; 1
# 0 1
# != 1
# % 1
# 0 1
# 10 1
# + 1
# remainder 1
# "%disanArmstrongnumber.\n" 1
# "%disanArmstrongnumber.\n" 1
# "%disanArmstrongnumber.\n" 1
# "%disnotanArmstrongnumber.\n" 1
# , 1
# n 1
# "%disnotanArmstrongnumber.\n" 1
# n 1
# , 1
# "%disnotanArmstrongnumber.\n" 1
# ; 1
# , 1
# n 1
# , 1
# "%disnotanArmstrongnumber.\n" 1
# "%disanArmstrongnumber.\n" 1
# "Inputaninteger\n" 1
# temp 1
# temp 1
# i 1
# = 1
# = 1
# ; 1
# ) 1
# ) 1
# power 1
# 10 1
# 10 1
# remainder 1
# temp 1
# 10 1
# ; 1
# power 1
# 10 1
# power 1
# 10 1
# ; 1
# 10 1
# / 1
# power 1
# 10 1
# power 1
# ; 1
# / 1
# 10 1
# / 1

# %%
#2,6,8
tokmap = {}
for d in data_np:
    temp = (d[2],d[6],d[8])
    if temp not in tokmap:
        tokmap[temp] = d[3]
    else:
        tokmap[temp] += d[3]

# %%
for key, val in sorted(tokmap.items(), key = lambda x: (x[1],x[0]),reverse = True):
    print(key,val)
# Out:
# ("'blank'", "'blank'", "'blank'") 588
# ('\'"%disnotanArmstrongnumber.\\n"\'', "'blank'", "'blank'") 132
# ('\'"Enteraninteger:"\'', "'blank'", "'blank'") 61
# ("'10'", "'ExpressionStatement'", "'while_body'") 51
# ('\'"Inputaninteger\\n"\'', "'blank'", "'blank'") 45
# ('\'"Error!Factorialofanegativenumberdoesn\'\'texist."\'', "'blank'", "'blank'") 40
# ("'factorial'", "'FunctionHeader'", "'blank'") 37
# ("'unsigned'", "'Declaration'", "'blank'") 33
# ('\'"Factorialof%d=%llu"\'', "'blank'", "'blank'") 31
# ("'negative'", "'blank'", "'blank'") 28
# ("'void'", "'FunctionHeader'", "'blank'") 27
# ('\'"%disanArmstrongnumber.\\n"\'', "'blank'", "'blank'") 26
# ("'printf'", "'blank'", "'blank'") 24
# ("'/'", "'ExpressionStatement'", "'while_body'") 22
# ("'factorial'", "'Declaration'", "'blank'") 20
# ("'remainder'", "'ExpressionStatement'", "'while_body'") 19
# ("'!='", "'While Header'", "'blank'") 19
# ("'temp'", "'ExpressionStatement'", "'while_body'") 17
# ("'include'", "'blank'", "'blank'") 17
# ("'show'", "'blank'", "'blank'") 13
# ("'scanf'", "'blank'", "'blank'") 13
# ("'n'", "'blank'", "'blank'") 13
# ("'factorial'", "'blank'", "'blank'") 13
# ("'0'", "'While Header'", "'blank'") 13
# ("'&'", "'blank'", "'blank'") 13
# ("'0'", "'Declaration'", "'blank'") 11
# ("'int'", "'Declaration'", "'blank'") 10
# ("'digits'", "'ExpressionStatement'", "'while_body'") 10
# ("';'", "'ExpressionStatement'", "'while_body'") 9
# ("')'", "'blank'", "'blank'") 9
# ('\'"%d"\'', "'blank'", "'blank'") 9
# ("'remainder'", "'Declaration'", "'blank'") 8
# ("'temp'", "'Declaration'", "'blank'") 7
# ("'power'", "'ExpressionStatement'", "'while_body'") 7
# ("'i'", "'ExpressionStatement'", "'for_body'") 7
# ("'digits'", "'Declaration'", "'blank'") 7
# ("';'", "'blank'", "'blank'") 7
# ("'long'", "'Declaration'", "'blank'") 6
# ("'='", "'Declaration'", "'blank'") 6
# ("'0'", "'IfHeader'", "'blank'") 5
# ("','", "'blank'", "'blank'") 5
# ("'*='", "'ExpressionStatement'", "'for_body'") 5
# ("'temp'", "'While Header'", "'blank'") 4
# ("'number'", "'blank'", "'blank'") 4
# ("'a'", "'blank'", "'blank'") 4
# ("'('", "'blank'", "'blank'") 4
# ("'user'", "'blank'", "'blank'") 3
# ("'error'", "'blank'", "'blank'") 3
# ("','", "'Declaration'", "'blank'") 3
# ("')'", "'While Header'", "'blank'") 3
# ("'unsigned_blank'", "'Declaration'", "'blank'") 2
# ("'stdio'", "'blank'", "'blank'") 2
# ("'digits'", "'blank'", "'blank'") 2
# ("'armstrong_no'", "'FunctionHeader'", "'blank'") 2
# ("'/'", "'blank'", "'blank'") 2
# ("'('", "'IfHeader'", "'blank'") 2
# ("'of'", "'blank'", "'blank'") 1
# ("'n'", "'IfHeader'", "'blank'") 1
# ("'n'", "'Declaration'", "'blank'") 1
# ("'='", "'ExpressionStatement'", "'while_body'") 1
# ("';'", "'Declaration'", "'blank'") 1
# ("'++'", "'ForHeader'", "'blank'") 1
# ("'+'", "'ExpressionStatement'", "'while_body'") 1
# ("'%'", "'ExpressionStatement'", "'while_body'") 1

# %%
srt_by_time = sorted(data_np,key = lambda x:x[5]-x[4],reverse=True)

# %%
srt_by_time = np.array(srt_by_time)
for data in srt_by_time:
    if data[2] != '\'blank\'':
        print(data[2][1:-1],data[5]-data[4])
# Out:
# "%disnotanArmstrongnumber.\n" 3503
# "Error!Factorialofanegativenumberdoesn''texist." 1051
# negative 800
# "%disnotanArmstrongnumber.\n" 612
# void 591
# "Factorialof%d=%llu" 556
# "Inputaninteger\n" 495
# "Enteraninteger:" 479
# / 443
# factorial 387
# "%disanArmstrongnumber.\n" 326
# factorial 307
# factorial 299
# unsigned 291
# 10 285
# != 285
# "Enteraninteger:" 255
# "Factorialof%d=%llu" 246
# factorial 232
# unsigned 228
# "Enteraninteger:" 222
# scanf 221
# void 196
# printf 192
# remainder 192
# != 190
# int 162
# factorial 158
# 0 158
# 10 158
# i 154
# "Inputaninteger\n" 130
# remainder 128
# factorial 127
# remainder 127
# remainder 126
# 10 126
# "Enteraninteger:" 125
# 0 125
# printf 123
# "%disanArmstrongnumber.\n" 98
# "%disanArmstrongnumber.\n" 97
# 10 96
# "Inputaninteger\n" 96
# show 95
# "Enteraninteger:" 94
# 0 94
# factorial 93
# a 93
# *= 92
# & 92
# digits 89
# include 79
# include 66
# int 66
# 10 66
# unsigned 65
# unsigned 64
# printf 64
# factorial 64
# printf 64
# 10 64
# "%disanArmstrongnumber.\n" 64
# 10 64
# "Enteraninteger:" 63
# scanf 63
# "Inputaninteger\n" 63
# 10 63
# temp 63
# ; 63
# show 62
# "Factorialof%d=%llu" 62
# "Inputaninteger\n" 62
# digits 62
# number 62
# "Inputaninteger\n" 62
# "Error!Factorialofanegativenumberdoesn''texist." 43
# digits 38
# include 34
# temp 34
# include 33
# include 33
# unsigned_blank 33
# "Enteraninteger:" 33
# temp 33
# long 32
# unsigned 32
# unsigned 32
# unsigned 32
# long 32
# factorial 32
# "Enteraninteger:" 32
# / 32
# "Inputaninteger\n" 32
# & 32
# n 32
# temp 32
# temp 32
# temp 32
# "Enteraninteger:" 31
# "%d" 31
# "%d" 31
# show 31
# ( 31
# factorial 31
# armstrong_no 31
# ) 31
# "Inputaninteger\n" 31
# temp 31
# 10 31
# / 31
# digits 31
# "%disnotanArmstrongnumber.\n" 31
# temp 31
# power 31
# 0 30
# = 30
# n 30
# & 25
# include 0
# include 0
# stdio 0
# stdio 0
# include 0
# include 0
# include 0
# factorial 0
# factorial 0
# void 0
# unsigned 0
# "Enteraninteger:" 0
# long 0
# int 0
# n 0
# unsigned 0
# printf 0
# printf 0
# unsigned 0
# printf 0
# printf 0
# ( 0
# "Enteraninteger:" 0
# & 0
# n 0
# "Enteraninteger:" 0
# long 0
# factorial 0
# factorial 0
# "Enteraninteger:" 0
# "Enteraninteger:" 0
# "Enteraninteger:" 0
# factorial 0
# "Enteraninteger:" 0
# "Enteraninteger:" 0
# printf 0
# scanf 0
# ( 0
# "Enteraninteger:" 0
# ( 0
# "%d" 0
# & 0
# n 0
# "Enteraninteger:" 0
# ) 0
# n 0
# ) 0
# & 0
# show 0
# scanf 0
# show 0
# error 0
# "%d" 0
# "%d" 0
# error 0
# ( 0
# "%d" 0
# show 0
# "%d" 0
# show 0
# n 0
# error 0
# "Error!Factorialofanegativenumberdoesn''texist." 0
# 0 0
# printf 0
# user 0
# factorial 0
# "Error!Factorialofanegativenumberdoesn''texist." 0
# user 0
# "Error!Factorialofanegativenumberdoesn''texist." 0
# user 0
# negative 0
# ++ 0
# *= 0
# temp 0
# , 0
# 0 0
# "Inputaninteger\n" 0
# = 0
# 0 0
# "Inputaninteger\n" 0
# "Inputaninteger\n" 0
# 0 0
# temp 0
# , 0
# temp 0
# ; 0
# ; 0
# remainder 0
# digits 0
# remainder 0
# ) 0
# ; 0
# , 0
# remainder 0
# ; 0
# ) 0
# digits 0
# ; 0
# digits 0
# = 0
# 0 0
# ; 0
# digits 0
# "Inputaninteger\n" 0
# n 0
# "Inputaninteger\n" 0
# & 0
# ) 0
# ; 0
# digits 0
# "Inputaninteger\n" 0
# digits 0
# n 0
# of 0
# n 0
# "Inputaninteger\n" 0
# ) 0
# & 0
# , 0
# number 0
# 0 0
# ) 0
# 0 0
# ) 0
# temp 0
# 10 0
# / 0
# / 0
# 10 0
# ; 0
# 0 0
# 10 0
# temp 0
# digits 0
# temp 0
# digits 0
# 0 0
# 0 0
# temp 0
# = 0
# != 0
# temp 0
# ; 0
# 0 0
# != 0
# % 0
# 0 0
# 10 0
# + 0
# remainder 0
# "%disanArmstrongnumber.\n" 0
# "%disanArmstrongnumber.\n" 0
# "%disanArmstrongnumber.\n" 0
# "%disnotanArmstrongnumber.\n" 0
# , 0
# n 0
# "%disnotanArmstrongnumber.\n" 0
# n 0
# , 0
# "%disnotanArmstrongnumber.\n" 0
# ; 0
# , 0
# n 0
# , 0
# "%disnotanArmstrongnumber.\n" 0
# "%disanArmstrongnumber.\n" 0
# "Inputaninteger\n" 0
# temp 0
# temp 0
# i 0
# = 0
# = 0
# ; 0
# ) 0
# ) 0
# power 0
# 10 0
# 10 0
# remainder 0
# temp 0
# 10 0
# ; 0
# power 0
# 10 0
# power 0
# 10 0
# ; 0
# 10 0
# / 0
# power 0
# 10 0
# power 0
# ; 0
# / 0
# 10 0
# / 0

# %%
tokmap_time = {}
for d in data_np:
    temp = (d[2],d[6],d[8])
    if temp not in tokmap_time:
        tokmap_time[temp] = d[5] - d[4]
    else:
        tokmap_time[temp] += d[5] - d[4]

# %%
for key, val in sorted(tokmap_time.items(), key = lambda x: (x[1],x[0]),reverse = True):
    print(key,val)
# Out:
# ("'blank'", "'blank'", "'blank'") 14596
# ('\'"%disnotanArmstrongnumber.\\n"\'', "'blank'", "'blank'") 4146
# ('\'"Enteraninteger:"\'', "'blank'", "'blank'") 1334
# ('\'"Error!Factorialofanegativenumberdoesn\'\'texist."\'', "'blank'", "'blank'") 1094
# ("'factorial'", "'FunctionHeader'", "'blank'") 1011
# ('\'"Inputaninteger\\n"\'', "'blank'", "'blank'") 971
# ("'10'", "'ExpressionStatement'", "'while_body'") 953
# ('\'"Factorialof%d=%llu"\'', "'blank'", "'blank'") 864
# ("'negative'", "'blank'", "'blank'") 800
# ("'void'", "'FunctionHeader'", "'blank'") 787
# ("'unsigned'", "'Declaration'", "'blank'") 744
# ('\'"%disanArmstrongnumber.\\n"\'', "'blank'", "'blank'") 585
# ("'!='", "'While Header'", "'blank'") 475
# ("'/'", "'ExpressionStatement'", "'while_body'") 474
# ("'remainder'", "'ExpressionStatement'", "'while_body'") 445
# ("'printf'", "'blank'", "'blank'") 443
# ("'factorial'", "'Declaration'", "'blank'") 381
# ("'factorial'", "'blank'", "'blank'") 338
# ("'scanf'", "'blank'", "'blank'") 284
# ("'include'", "'blank'", "'blank'") 245
# ("'int'", "'Declaration'", "'blank'") 228
# ("'temp'", "'ExpressionStatement'", "'while_body'") 192
# ("'show'", "'blank'", "'blank'") 188
# ("'digits'", "'ExpressionStatement'", "'while_body'") 158
# ("'0'", "'While Header'", "'blank'") 158
# ("'0'", "'Declaration'", "'blank'") 155
# ("'i'", "'ExpressionStatement'", "'for_body'") 154
# ("'&'", "'blank'", "'blank'") 149
# ("'remainder'", "'Declaration'", "'blank'") 128
# ("'0'", "'IfHeader'", "'blank'") 94
# ("'a'", "'blank'", "'blank'") 93
# ("'*='", "'ExpressionStatement'", "'for_body'") 92
# ("'temp'", "'While Header'", "'blank'") 65
# ("'long'", "'Declaration'", "'blank'") 64
# ("';'", "'ExpressionStatement'", "'while_body'") 63
# ("'number'", "'blank'", "'blank'") 62
# ("'n'", "'blank'", "'blank'") 62
# ("'digits'", "'Declaration'", "'blank'") 62
# ('\'"%d"\'', "'blank'", "'blank'") 62
# ("'unsigned_blank'", "'Declaration'", "'blank'") 33
# ("'/'", "'blank'", "'blank'") 32
# ("'temp'", "'Declaration'", "'blank'") 31
# ("'power'", "'ExpressionStatement'", "'while_body'") 31
# ("'armstrong_no'", "'FunctionHeader'", "'blank'") 31
# ("')'", "'blank'", "'blank'") 31
# ("'('", "'IfHeader'", "'blank'") 31
# ("'='", "'Declaration'", "'blank'") 30
# ("'user'", "'blank'", "'blank'") 0
# ("'stdio'", "'blank'", "'blank'") 0
# ("'of'", "'blank'", "'blank'") 0
# ("'n'", "'IfHeader'", "'blank'") 0
# ("'n'", "'Declaration'", "'blank'") 0
# ("'error'", "'blank'", "'blank'") 0
# ("'digits'", "'blank'", "'blank'") 0
# ("'='", "'ExpressionStatement'", "'while_body'") 0
# ("';'", "'blank'", "'blank'") 0
# ("';'", "'Declaration'", "'blank'") 0
# ("','", "'blank'", "'blank'") 0
# ("','", "'Declaration'", "'blank'") 0
# ("'++'", "'ForHeader'", "'blank'") 0
# ("'+'", "'ExpressionStatement'", "'while_body'") 0
# ("')'", "'While Header'", "'blank'") 0
# ("'('", "'blank'", "'blank'") 0
# ("'%'", "'ExpressionStatement'", "'while_body'") 0
